# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import Sequential
from sklearn.model_selection import train_test_split, cross_val_score

# %% [markdown]
# **Import csv, clean & process data**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b13d4052-0da9-43e5-913f-16fdbf087cde" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b13d4052-0da9-43e5-913f-16fdbf087cde">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_absenteeism = pd.read_csv('2016-17_-_2020-21_School_End-of-Year_Attendance_and_Chronic_Absenteeism_Data.csv')
df.head()
# Out:
#       DBN                School Name       Grade      Category     Year  \
# 0  01M015  P.S. 015 Roberto Clemente  All Grades  All Students  2016-17
# 1  01M015  P.S. 015 Roberto Clemente  All Grades  All Students  2017-18
# 2  01M015  P.S. 015 Roberto Clemente  All Grades  All Students  2018-19
# 3  01M015  P.S. 015 Roberto Clemente  All Grades  All Students  2019-20
# 4  01M015  P.S. 015 Roberto Clemente  All Grades  All Students  2020-21
#
#    # Total Days # Days Absent # Days Present % Attendance  \
# 0         30601          1994          28607         93.5
# 1         33264          2078          31186         93.8
# 2         30887          2278          28609         92.6
# 3         21101          1500          19601         92.9
# 4         32686          3931          28755         88.0
#
#   # Contributing 10+ Total Days and 1+ Pres Day # Chronically Absent  \
# 0                                           196                   51
# ...

# %%
df_eagle = df_absenteeism[df_absenteeism['DBN'].str.contains('09X231')]
df_eagle.head(10)
# Out:
#           DBN                  School Name       Grade      Category     Year  \
# 13459  09X231  Eagle Academy for Young Men  All Grades  All Students  2016-17
# 13460  09X231  Eagle Academy for Young Men  All Grades  All Students  2017-18
# 13461  09X231  Eagle Academy for Young Men  All Grades  All Students  2018-19
# 13462  09X231  Eagle Academy for Young Men  All Grades  All Students  2019-20
# 13463  09X231  Eagle Academy for Young Men  All Grades  All Students  2020-21
# 13464  09X231  Eagle Academy for Young Men           6  All Students  2016-17
# 13465  09X231  Eagle Academy for Young Men           6  All Students  2017-18
# 13466  09X231  Eagle Academy for Young Men           6  All Students  2018-19
# 13467  09X231  Eagle Academy for Young Men           6  All Students  2019-20
# 13468  09X231  Eagle Academy for Young Men           6  All Students  2020-21
#
#        # Total Days # Days Absent # Days Present % Attendance  \
# ...

# %%
df_eagle_all = df_eagle.head(5)
print(df_eagle_all['% Attendance'].astype(float).sort_values(ascending= True))
# Out:
# 13463    83.5
# 13459    89.1
# 13460    89.6
# 13461    91.2
# 13462    92.0
# Name: % Attendance, dtype: float64

# %% [markdown]
# **Visualiziing Data**

# %%
x= list(df_eagle_all.Year)
y= list(df_eagle_all['% Attendance'].astype(float))

plt.figure(figsize = (10, 5))

plt.ylim(80.0,94.0 )
plt.bar(x, y, color= 'red', width= 0.4)


plt.ylabel('Attendance %')
plt.xlabel('School Years')
plt.title('Eagle Bronx Attendance Trends')
plt.show()
